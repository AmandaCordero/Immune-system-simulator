# %%
corrida= [{'plasma_production_factor': 0.01, 'memory_production_factor': 0.0002762648216661518}
,{'plasma_production_factor': 0.01, 'memory_production_factor': 0.002}
,{'plasma_production_factor': 0.01014754089016327, 'memory_production_factor': 0.0002762648216661518}
,{'plasma_production_factor': 0.01014754089016327, 'memory_production_factor': 0.001818251268448227}
,{'plasma_production_factor': 0.014574992560292259, 'memory_production_factor': 0.001818251268448227}
,{'plasma_production_factor': 0.01014754089016327, 'memory_production_factor': 0.0017157161365098901}
,{'plasma_production_factor': 0.009829865171234128, 'memory_production_factor': 0.0017157161365098901}
,{'plasma_production_factor': 0.013366875786215517, 'memory_production_factor': 0.0017157161365098901}
,{'plasma_production_factor': 0.012025547027435224, 'memory_production_factor': 0.0017157161365098901}
,{'plasma_production_factor': 0.00770937809706974, 'memory_production_factor': 0.0017157161365098901}
,{'plasma_production_factor': 0.00770937809706974, 'memory_production_factor': 0.0009442608210970668}
,{'plasma_production_factor': 0.00770937809706974, 'memory_production_factor': 0}
,{'plasma_production_factor': 0.00770937809706974, 'memory_production_factor': 0}
,{'plasma_production_factor': 0.00770937809706974, 'memory_production_factor': 0}
,{'plasma_production_factor': 0.00770937809706974, 'memory_production_factor': 0}
,{'plasma_production_factor': 0.01229509861648065, 'memory_production_factor': 0}
,{'plasma_production_factor': 0.01229509861648065, 'memory_production_factor': 0.004286873838846823}
,{'plasma_production_factor': 0.01667710922132677, 'memory_production_factor': 0}
,{'plasma_production_factor': 0.01229509861648065, 'memory_production_factor': 0.00391383759115094}
,{'plasma_production_factor': 0.00959841514878532, 'memory_production_factor': 0}
,{'plasma_production_factor': 0.012023145953257932, 'memory_production_factor': 0}
,{'plasma_production_factor': 0.01229509861648065, 'memory_production_factor': 0.0004412373242880163}
,{'plasma_production_factor': 0.01431357063248762, 'memory_production_factor': 0.0004412373242880163}
,{'plasma_production_factor': 0.010602973390538267, 'memory_production_factor': 0.0004412373242880163}
,{'plasma_production_factor': 0.01229509861648065, 'memory_production_factor': 0.003626480688458892}
,{'plasma_production_factor': 0.008930007265426029, 'memory_production_factor': 0.0004412373242880163}
,{'plasma_production_factor': 0.00755501805834602, 'memory_production_factor': 0.0004412373242880163}
,{'plasma_production_factor': 0.01229509861648065, 'memory_production_factor': 0.0028793923939579823}
,{'plasma_production_factor': 0.01229509861648065, 'memory_production_factor': 0.002620238067498031}
,{'plasma_production_factor': 0.01229509861648065, 'memory_production_factor': 0.0007787190031602002}
,{'plasma_production_factor': 0.010639007540727866, 'memory_production_factor': 0.0007787190031602002}
,{'plasma_production_factor': 0.009563115201781618, 'memory_production_factor': 0.0007787190031602002}
,{'plasma_production_factor': 0.0050007651229483354, 'memory_production_factor': 0.0007787190031602002}
,{'plasma_production_factor': 0.007201997685193265, 'memory_production_factor': 0.0007787190031602002}
,{'plasma_production_factor': 0.011944898951589535, 'memory_production_factor': 0.0007787190031602002}
,{'plasma_production_factor': 0.00897092145366183, 'memory_production_factor': 0.0007787190031602002}
,{'plasma_production_factor': 0.007201997685193265, 'memory_production_factor': 0.0013901015438226565}
,{'plasma_production_factor': 0.006343577996711735, 'memory_production_factor': 0.0007787190031602002}
,{'plasma_production_factor': 0.0024586132695970627, 'memory_production_factor': 0.0007787190031602002}
,{'plasma_production_factor': 0.007201997685193265, 'memory_production_factor': 0.00561560724093993}
,{'plasma_production_factor': 0.0036811993535738555, 'memory_production_factor': 0.0007787190031602002}
,{'plasma_production_factor': 0.007201997685193265, 'memory_production_factor': 0}
,{'plasma_production_factor': 0.007201997685193265, 'memory_production_factor': 0}
,{'plasma_production_factor': 0.007201997685193265, 'memory_production_factor': 0.0013143088291436905}
,{'plasma_production_factor': 0.008967559791802904, 'memory_production_factor': 0.0007787190031602002}]

# %%
plasma = [c['plasma_production_factor'] for c in corrida]
memoria = [c['memory_production_factor'] for c in corrida]

# %%
'plasma_production_factor': 0.007201997685193265, 'memory_production_factor': 0.0007787190031602002

# %%
from matplotlib import pyplot as plt
# Graficar puntos
plt.scatter(plasma, memoria, color='red', label='Puntos')

# Conectar puntos con línea en orden
plt.plot(plasma, memoria, color='blue', label='Conexión')

plt.scatter(0.007201997685193265, 0.0007787190031602002, color= 'yellow', label = 'final')


# Etiquetas y título
plt.xlabel('Componente plasma')
plt.ylabel('Componente memoria')
plt.title('Puntos en R2 conectados en orden')
plt.legend()
plt.grid(True)

# Mostrar gráfica
plt.show()

# %%
ener= [3.6430560891921178, 2.862165150479258,6.398539255312125, 2.937215110761238,2.8991336210645295,7.0720137974527635,2.755916451268889

# %%
plt.scatter(plasma, memoria, color='red', label='Puntos')

# Conectar puntos con línea en orden
plt.plot(plasma, memoria, color='blue', label='Conexión')

plt.scatter(0.007201997685193265, 0.0007787190031602002, color= 'yellow', label = 'final')


# Etiquetas y título
plt.xlabel('Componente plasma')
plt.ylabel('Componente memoria')
plt.title('Puntos en R2 conectados en orden')
plt.legend()
plt.grid(True)

# Mostrar gráfica
plt.show()
